# %% [markdown]
# # Dataset
# Note: The database is publicly available for non-commercial use.
#
# Please refer to [Schuldt, Laptev and Caputo, Proc. ICPR'04, Cambridge, UK ] if you use this database in your publications.
#
# This database contains sequences of six classes of actions :
# * walking.zip (242Mb)
# * jogging.zip (168Mb)
# * running.zip (149Mb)
# * boxing.zip (194Mb)
# * handwaving.zip (218Mb)
# * handclapping.zip (176Mb)
#
# [Dataset link](http://www.nada.kth.se/cvap/actions/)

# %% [markdown]
# ## Downloading Dataset
# Remove "!" if you are runnning this script on your local machine.

# %%
# !mkdir dataset
# !mkdir data

# %%
# !wget http://www.nada.kth.se/cvap/actions/boxing.zip
# !wget http://www.nada.kth.se/cvap/actions/handclapping.zip
# !wget http://www.nada.kth.se/cvap/actions/handwaving.zip
# !wget http://www.nada.kth.se/cvap/actions/jogging.zip
# !wget http://www.nada.kth.se/cvap/actions/running.zip
# !wget http://www.nada.kth.se/cvap/actions/walking.zip
# !wget http://www.nada.kth.se/cvap/actions/00sequences.txt -P dataset

# !unzip boxing.zip -d dataset/boxing
# !unzip handclapping.zip -d dataset/handclapping
# !unzip handwaving.zip -d dataset/handwaving
# !unzip jogging.zip -d dataset/jogging
# !unzip running.zip -d dataset/running
# !unzip walking.zip -d dataset/walking

# !rm *.zip
# Out:
# --2019-11-25 21:15:43--  http://www.nada.kth.se/cvap/actions/boxing.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘boxing.zip’
#
# boxing.zip              [       <=>          ] 185.49M  18.5MB/s    in 9.1s
#
# 2019-11-25 21:15:52 (20.4 MB/s) - ‘boxing.zip’ saved [194498294]
#
# --2019-11-25 21:15:54--  http://www.nada.kth.se/cvap/actions/handclapping.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘handclapping.zip’
#
# handclapping.zip        [  <=>               ] 168.71M  23.6MB/s    in 7.6s
#
# 2019-11-25 21:16:02 (22.3 MB/s) - ‘handclapping.zip’ saved [176901831]
#
# --2019-11-25 21:16:03--  http://www.nada.kth.se/cvap/actions/handwaving.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘handwaving.zip’
#
# handwaving.zip          [        <=>         ] 208.84M  22.7MB/s    in 9.2s
#
# 2019-11-25 21:16:13 (22.8 MB/s) - ‘handwaving.zip’ saved [218981954]
#
# --2019-11-25 21:16:15--  http://www.nada.kth.se/cvap/actions/jogging.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘jogging.zip’
#
# jogging.zip             [  <=>               ] 161.13M  23.8MB/s    in 7.5s
#
# 2019-11-25 21:16:22 (21.5 MB/s) - ‘jogging.zip’ saved [168961290]
#
# --2019-11-25 21:16:23--  http://www.nada.kth.se/cvap/actions/running.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘running.zip’
#
# running.zip             [    <=>             ] 142.82M  25.6MB/s    in 6.4s
#
# 2019-11-25 21:16:30 (22.4 MB/s) - ‘running.zip’ saved [149756643]
#
# --2019-11-25 21:16:31--  http://www.nada.kth.se/cvap/actions/walking.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘walking.zip’
#
# walking.zip             [            <=>     ] 231.21M  26.4MB/s    in 9.8s
#
# 2019-11-25 21:16:41 (23.5 MB/s) - ‘walking.zip’ saved [242442411]
#
# --2019-11-25 21:16:42--  http://www.nada.kth.se/cvap/actions/00sequences.txt
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.227.116
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.227.116|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38292 (37K) [text/plain]
# Saving to: ‘dataset/00sequences.txt’
#
# 00sequences.txt     100%[===================>]  37.39K  --.-KB/s    in 0.09s
#
# 2019-11-25 21:16:43 (399 KB/s) - ‘dataset/00sequences.txt’ saved [38292/38292]
#
# Archive:  boxing.zip
#   inflating: dataset/boxing/person01_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person01_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person01_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person01_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person02_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person02_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person02_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person02_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person03_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person03_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person03_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person03_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person04_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person04_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person04_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person04_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person05_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person05_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person05_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person05_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person06_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person06_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person06_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person06_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person07_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person07_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person07_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person07_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person08_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person08_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person08_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person08_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person09_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person09_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person09_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person09_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person10_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person10_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person10_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person10_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person11_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person11_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person11_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person11_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person12_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person12_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person12_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person12_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person13_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person13_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person13_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person13_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person14_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person14_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person14_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person14_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person15_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person15_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person15_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person15_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person16_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person16_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person16_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person16_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person17_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person17_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person17_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person17_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person18_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person18_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person18_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person18_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person19_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person19_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person19_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person19_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person20_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person20_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person20_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person20_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person21_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person21_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person21_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person21_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person22_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person22_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person22_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person22_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person23_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person23_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person23_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person23_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person24_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person24_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person24_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person24_boxing_d4_uncomp.avi
#   inflating: dataset/boxing/person25_boxing_d1_uncomp.avi
#   inflating: dataset/boxing/person25_boxing_d2_uncomp.avi
#   inflating: dataset/boxing/person25_boxing_d3_uncomp.avi
#   inflating: dataset/boxing/person25_boxing_d4_uncomp.avi
# Archive:  handclapping.zip
#   inflating: dataset/handclapping/person01_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person01_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person01_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person01_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person02_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person02_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person02_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person02_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person03_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person03_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person03_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person03_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person04_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person04_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person04_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person04_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person05_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person05_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person05_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person05_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person06_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person06_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person06_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person06_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person07_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person07_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person07_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person07_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person08_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person08_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person08_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person08_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person09_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person09_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person09_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person09_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person10_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person10_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person10_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person10_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person11_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person11_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person11_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person11_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person12_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person12_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person12_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person12_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person13_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person13_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person13_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person14_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person14_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person14_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person14_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person15_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person15_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person15_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person15_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person16_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person16_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person16_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person16_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person17_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person17_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person17_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person17_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person18_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person18_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person18_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person18_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person19_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person19_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person19_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person19_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person20_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person20_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person20_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person20_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person21_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person21_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person21_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person21_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person22_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person22_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person22_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person22_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person23_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person23_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person23_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person23_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person24_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person24_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person24_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person24_handclapping_d4_uncomp.avi
#   inflating: dataset/handclapping/person25_handclapping_d1_uncomp.avi
#   inflating: dataset/handclapping/person25_handclapping_d2_uncomp.avi
#   inflating: dataset/handclapping/person25_handclapping_d3_uncomp.avi
#   inflating: dataset/handclapping/person25_handclapping_d4_uncomp.avi
# Archive:  handwaving.zip
#   inflating: dataset/handwaving/person01_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person01_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person01_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person01_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person02_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person02_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person02_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person02_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person03_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person03_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person03_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person03_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person04_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person04_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person04_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person04_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person05_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person05_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person05_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person05_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person06_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person06_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person06_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person06_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person07_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person07_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person07_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person07_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person08_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person08_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person08_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person08_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person09_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person09_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person09_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person09_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person10_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person10_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person10_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person10_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person11_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person11_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person11_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person11_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person12_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person12_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person12_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person12_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person13_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person13_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person13_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person13_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person14_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person14_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person14_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person14_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person15_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person15_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person15_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person15_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person16_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person16_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person16_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person16_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person17_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person17_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person17_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person17_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person18_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person18_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person18_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person18_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person19_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person19_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person19_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person19_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person20_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person20_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person20_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person20_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person21_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person21_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person21_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person21_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person22_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person22_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person22_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person22_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person23_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person23_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person23_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person23_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person24_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person24_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person24_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person24_handwaving_d4_uncomp.avi
#   inflating: dataset/handwaving/person25_handwaving_d1_uncomp.avi
#   inflating: dataset/handwaving/person25_handwaving_d2_uncomp.avi
#   inflating: dataset/handwaving/person25_handwaving_d3_uncomp.avi
#   inflating: dataset/handwaving/person25_handwaving_d4_uncomp.avi
# Archive:  jogging.zip
#   inflating: dataset/jogging/person01_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person01_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person01_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person01_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person02_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person02_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person02_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person02_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person03_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person03_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person03_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person03_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person04_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person04_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person04_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person04_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person05_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person05_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person05_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person05_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person06_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person06_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person06_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person06_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person07_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person07_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person07_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person07_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person08_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person08_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person08_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person08_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person09_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person09_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person09_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person09_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person10_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person10_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person10_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person10_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person11_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person11_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person11_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person11_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person12_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person12_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person12_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person12_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person13_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person13_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person13_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person13_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person14_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person14_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person14_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person14_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person15_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person15_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person15_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person15_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person16_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person16_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person16_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person16_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person17_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person17_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person17_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person17_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person18_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person18_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person18_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person18_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person19_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person19_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person19_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person19_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person20_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person20_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person20_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person20_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person21_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person21_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person21_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person21_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person22_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person22_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person22_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person22_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person23_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person23_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person23_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person23_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person24_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person24_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person24_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person24_jogging_d4_uncomp.avi
#   inflating: dataset/jogging/person25_jogging_d1_uncomp.avi
#   inflating: dataset/jogging/person25_jogging_d2_uncomp.avi
#   inflating: dataset/jogging/person25_jogging_d3_uncomp.avi
#   inflating: dataset/jogging/person25_jogging_d4_uncomp.avi
# Archive:  running.zip
#   inflating: dataset/running/person01_running_d1_uncomp.avi
#   inflating: dataset/running/person01_running_d2_uncomp.avi
#   inflating: dataset/running/person01_running_d3_uncomp.avi
#   inflating: dataset/running/person01_running_d4_uncomp.avi
#   inflating: dataset/running/person02_running_d1_uncomp.avi
#   inflating: dataset/running/person02_running_d2_uncomp.avi
#   inflating: dataset/running/person02_running_d3_uncomp.avi
#   inflating: dataset/running/person02_running_d4_uncomp.avi
#   inflating: dataset/running/person03_running_d1_uncomp.avi
#   inflating: dataset/running/person03_running_d2_uncomp.avi
#   inflating: dataset/running/person03_running_d3_uncomp.avi
#   inflating: dataset/running/person03_running_d4_uncomp.avi
#   inflating: dataset/running/person04_running_d1_uncomp.avi
#   inflating: dataset/running/person04_running_d2_uncomp.avi
#   inflating: dataset/running/person04_running_d3_uncomp.avi
#   inflating: dataset/running/person04_running_d4_uncomp.avi
#   inflating: dataset/running/person05_running_d1_uncomp.avi
#   inflating: dataset/running/person05_running_d2_uncomp.avi
#   inflating: dataset/running/person05_running_d3_uncomp.avi
#   inflating: dataset/running/person05_running_d4_uncomp.avi
#   inflating: dataset/running/person06_running_d1_uncomp.avi
#   inflating: dataset/running/person06_running_d2_uncomp.avi
#   inflating: dataset/running/person06_running_d3_uncomp.avi
#   inflating: dataset/running/person06_running_d4_uncomp.avi
#   inflating: dataset/running/person07_running_d1_uncomp.avi
#   inflating: dataset/running/person07_running_d2_uncomp.avi
#   inflating: dataset/running/person07_running_d3_uncomp.avi
#   inflating: dataset/running/person07_running_d4_uncomp.avi
#   inflating: dataset/running/person08_running_d1_uncomp.avi
#   inflating: dataset/running/person08_running_d2_uncomp.avi
#   inflating: dataset/running/person08_running_d3_uncomp.avi
#   inflating: dataset/running/person08_running_d4_uncomp.avi
#   inflating: dataset/running/person09_running_d1_uncomp.avi
#   inflating: dataset/running/person09_running_d2_uncomp.avi
#   inflating: dataset/running/person09_running_d3_uncomp.avi
#   inflating: dataset/running/person09_running_d4_uncomp.avi
#   inflating: dataset/running/person10_running_d1_uncomp.avi
#   inflating: dataset/running/person10_running_d2_uncomp.avi
#   inflating: dataset/running/person10_running_d3_uncomp.avi
#   inflating: dataset/running/person10_running_d4_uncomp.avi
#   inflating: dataset/running/person11_running_d1_uncomp.avi
#   inflating: dataset/running/person11_running_d2_uncomp.avi
#   inflating: dataset/running/person11_running_d3_uncomp.avi
#   inflating: dataset/running/person11_running_d4_uncomp.avi
#   inflating: dataset/running/person12_running_d1_uncomp.avi
#   inflating: dataset/running/person12_running_d2_uncomp.avi
#   inflating: dataset/running/person12_running_d3_uncomp.avi
#   inflating: dataset/running/person12_running_d4_uncomp.avi
#   inflating: dataset/running/person13_running_d1_uncomp.avi
#   inflating: dataset/running/person13_running_d2_uncomp.avi
#   inflating: dataset/running/person13_running_d3_uncomp.avi
#   inflating: dataset/running/person13_running_d4_uncomp.avi
#   inflating: dataset/running/person14_running_d1_uncomp.avi
#   inflating: dataset/running/person14_running_d2_uncomp.avi
#   inflating: dataset/running/person14_running_d3_uncomp.avi
#   inflating: dataset/running/person14_running_d4_uncomp.avi
#   inflating: dataset/running/person15_running_d1_uncomp.avi
#   inflating: dataset/running/person15_running_d2_uncomp.avi
#   inflating: dataset/running/person15_running_d3_uncomp.avi
#   inflating: dataset/running/person15_running_d4_uncomp.avi
#   inflating: dataset/running/person16_running_d1_uncomp.avi
#   inflating: dataset/running/person16_running_d2_uncomp.avi
#   inflating: dataset/running/person16_running_d3_uncomp.avi
#   inflating: dataset/running/person16_running_d4_uncomp.avi
#   inflating: dataset/running/person17_running_d1_uncomp.avi
#   inflating: dataset/running/person17_running_d2_uncomp.avi
#   inflating: dataset/running/person17_running_d3_uncomp.avi
#   inflating: dataset/running/person17_running_d4_uncomp.avi
#   inflating: dataset/running/person18_running_d1_uncomp.avi
#   inflating: dataset/running/person18_running_d2_uncomp.avi
#   inflating: dataset/running/person18_running_d3_uncomp.avi
#   inflating: dataset/running/person18_running_d4_uncomp.avi
#   inflating: dataset/running/person19_running_d1_uncomp.avi
#   inflating: dataset/running/person19_running_d2_uncomp.avi
#   inflating: dataset/running/person19_running_d3_uncomp.avi
#   inflating: dataset/running/person19_running_d4_uncomp.avi
#   inflating: dataset/running/person20_running_d1_uncomp.avi
#   inflating: dataset/running/person20_running_d2_uncomp.avi
#   inflating: dataset/running/person20_running_d3_uncomp.avi
#   inflating: dataset/running/person20_running_d4_uncomp.avi
#   inflating: dataset/running/person21_running_d1_uncomp.avi
#   inflating: dataset/running/person21_running_d2_uncomp.avi
#   inflating: dataset/running/person21_running_d3_uncomp.avi
#   inflating: dataset/running/person21_running_d4_uncomp.avi
#   inflating: dataset/running/person22_running_d1_uncomp.avi
#   inflating: dataset/running/person22_running_d2_uncomp.avi
#   inflating: dataset/running/person22_running_d3_uncomp.avi
#   inflating: dataset/running/person22_running_d4_uncomp.avi
#   inflating: dataset/running/person23_running_d1_uncomp.avi
#   inflating: dataset/running/person23_running_d2_uncomp.avi
#   inflating: dataset/running/person23_running_d3_uncomp.avi
#   inflating: dataset/running/person23_running_d4_uncomp.avi
#   inflating: dataset/running/person24_running_d1_uncomp.avi
#   inflating: dataset/running/person24_running_d2_uncomp.avi
#   inflating: dataset/running/person24_running_d3_uncomp.avi
#   inflating: dataset/running/person24_running_d4_uncomp.avi
#   inflating: dataset/running/person25_running_d1_uncomp.avi
#   inflating: dataset/running/person25_running_d2_uncomp.avi
#   inflating: dataset/running/person25_running_d3_uncomp.avi
#   inflating: dataset/running/person25_running_d4_uncomp.avi
# Archive:  walking.zip
#   inflating: dataset/walking/person01_walking_d1_uncomp.avi
#   inflating: dataset/walking/person01_walking_d2_uncomp.avi
#   inflating: dataset/walking/person01_walking_d3_uncomp.avi
#   inflating: dataset/walking/person01_walking_d4_uncomp.avi
#   inflating: dataset/walking/person02_walking_d1_uncomp.avi
#   inflating: dataset/walking/person02_walking_d2_uncomp.avi
#   inflating: dataset/walking/person02_walking_d3_uncomp.avi
#   inflating: dataset/walking/person02_walking_d4_uncomp.avi
#   inflating: dataset/walking/person03_walking_d1_uncomp.avi
#   inflating: dataset/walking/person03_walking_d2_uncomp.avi
#   inflating: dataset/walking/person03_walking_d3_uncomp.avi
#   inflating: dataset/walking/person03_walking_d4_uncomp.avi
#   inflating: dataset/walking/person04_walking_d1_uncomp.avi
#   inflating: dataset/walking/person04_walking_d2_uncomp.avi
#   inflating: dataset/walking/person04_walking_d3_uncomp.avi
#   inflating: dataset/walking/person04_walking_d4_uncomp.avi
#   inflating: dataset/walking/person05_walking_d1_uncomp.avi
#   inflating: dataset/walking/person05_walking_d2_uncomp.avi
#   inflating: dataset/walking/person05_walking_d3_uncomp.avi
#   inflating: dataset/walking/person05_walking_d4_uncomp.avi
#   inflating: dataset/walking/person06_walking_d1_uncomp.avi
#   inflating: dataset/walking/person06_walking_d2_uncomp.avi
#   inflating: dataset/walking/person06_walking_d3_uncomp.avi
#   inflating: dataset/walking/person06_walking_d4_uncomp.avi
#   inflating: dataset/walking/person07_walking_d1_uncomp.avi
#   inflating: dataset/walking/person07_walking_d2_uncomp.avi
#   inflating: dataset/walking/person07_walking_d3_uncomp.avi
#   inflating: dataset/walking/person07_walking_d4_uncomp.avi
#   inflating: dataset/walking/person08_walking_d1_uncomp.avi
#   inflating: dataset/walking/person08_walking_d2_uncomp.avi
#   inflating: dataset/walking/person08_walking_d3_uncomp.avi
#   inflating: dataset/walking/person08_walking_d4_uncomp.avi
#   inflating: dataset/walking/person09_walking_d1_uncomp.avi
#   inflating: dataset/walking/person09_walking_d2_uncomp.avi
#   inflating: dataset/walking/person09_walking_d3_uncomp.avi
#   inflating: dataset/walking/person09_walking_d4_uncomp.avi
#   inflating: dataset/walking/person10_walking_d1_uncomp.avi
#   inflating: dataset/walking/person10_walking_d2_uncomp.avi
#   inflating: dataset/walking/person10_walking_d3_uncomp.avi
#   inflating: dataset/walking/person10_walking_d4_uncomp.avi
#   inflating: dataset/walking/person11_walking_d1_uncomp.avi
#   inflating: dataset/walking/person11_walking_d2_uncomp.avi
#   inflating: dataset/walking/person11_walking_d3_uncomp.avi
#   inflating: dataset/walking/person11_walking_d4_uncomp.avi
#   inflating: dataset/walking/person12_walking_d1_uncomp.avi
#   inflating: dataset/walking/person12_walking_d2_uncomp.avi
#   inflating: dataset/walking/person12_walking_d3_uncomp.avi
#   inflating: dataset/walking/person12_walking_d4_uncomp.avi
#   inflating: dataset/walking/person13_walking_d1_uncomp.avi
#   inflating: dataset/walking/person13_walking_d2_uncomp.avi
#   inflating: dataset/walking/person13_walking_d3_uncomp.avi
#   inflating: dataset/walking/person13_walking_d4_uncomp.avi
#   inflating: dataset/walking/person14_walking_d1_uncomp.avi
#   inflating: dataset/walking/person14_walking_d2_uncomp.avi
#   inflating: dataset/walking/person14_walking_d3_uncomp.avi
#   inflating: dataset/walking/person14_walking_d4_uncomp.avi
#   inflating: dataset/walking/person15_walking_d1_uncomp.avi
#   inflating: dataset/walking/person15_walking_d2_uncomp.avi
#   inflating: dataset/walking/person15_walking_d3_uncomp.avi
#   inflating: dataset/walking/person15_walking_d4_uncomp.avi
#   inflating: dataset/walking/person16_walking_d1_uncomp.avi
#   inflating: dataset/walking/person16_walking_d2_uncomp.avi
#   inflating: dataset/walking/person16_walking_d3_uncomp.avi
#   inflating: dataset/walking/person16_walking_d4_uncomp.avi
#   inflating: dataset/walking/person17_walking_d1_uncomp.avi
#   inflating: dataset/walking/person17_walking_d2_uncomp.avi
#   inflating: dataset/walking/person17_walking_d3_uncomp.avi
#   inflating: dataset/walking/person17_walking_d4_uncomp.avi
#   inflating: dataset/walking/person18_walking_d1_uncomp.avi
#   inflating: dataset/walking/person18_walking_d2_uncomp.avi
#   inflating: dataset/walking/person18_walking_d3_uncomp.avi
#   inflating: dataset/walking/person18_walking_d4_uncomp.avi
#   inflating: dataset/walking/person19_walking_d1_uncomp.avi
#   inflating: dataset/walking/person19_walking_d2_uncomp.avi
#   inflating: dataset/walking/person19_walking_d3_uncomp.avi
#   inflating: dataset/walking/person19_walking_d4_uncomp.avi
#   inflating: dataset/walking/person20_walking_d1_uncomp.avi
#   inflating: dataset/walking/person20_walking_d2_uncomp.avi
#   inflating: dataset/walking/person20_walking_d3_uncomp.avi
#   inflating: dataset/walking/person20_walking_d4_uncomp.avi
#   inflating: dataset/walking/person21_walking_d1_uncomp.avi
#   inflating: dataset/walking/person21_walking_d2_uncomp.avi
#   inflating: dataset/walking/person21_walking_d3_uncomp.avi
#   inflating: dataset/walking/person21_walking_d4_uncomp.avi
#   inflating: dataset/walking/person22_walking_d1_uncomp.avi
#   inflating: dataset/walking/person22_walking_d2_uncomp.avi
#   inflating: dataset/walking/person22_walking_d3_uncomp.avi
#   inflating: dataset/walking/person22_walking_d4_uncomp.avi
#   inflating: dataset/walking/person23_walking_d1_uncomp.avi
#   inflating: dataset/walking/person23_walking_d2_uncomp.avi
#   inflating: dataset/walking/person23_walking_d3_uncomp.avi
#   inflating: dataset/walking/person23_walking_d4_uncomp.avi
#   inflating: dataset/walking/person24_walking_d1_uncomp.avi
#   inflating: dataset/walking/person24_walking_d2_uncomp.avi
#   inflating: dataset/walking/person24_walking_d3_uncomp.avi
#   inflating: dataset/walking/person24_walking_d4_uncomp.avi
#   inflating: dataset/walking/person25_walking_d1_uncomp.avi
#   inflating: dataset/walking/person25_walking_d2_uncomp.avi
#   inflating: dataset/walking/person25_walking_d3_uncomp.avi
#   inflating: dataset/walking/person25_walking_d4_uncomp.avi

# %%
import cv2
cv2.__version__
# Out:
# '3.4.3'

# %%
import numpy as np
import os
import pickle
import PIL
import re
from PIL import Image
import imageio

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 76kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.17.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.3.2
#     Uninstalling scipy-1.3.2:
#       Successfully uninstalled scipy-1.3.2
# Successfully installed scipy-1.1.0

# %%
from scipy.misc.pilutil import imresize

# %%
CATEGORIES = [
    "boxing",
    "handclapping",
    "handwaving",
    "jogging",
    "running",
    "walking"
]

# %% [markdown]
# ## Spliting Dataset
# Dataset divided according to the instruction at:
#
# http://www.nada.kth.se/cvap/actions/00sequences.txt

# %%
TRAIN_PEOPLE_ID = [11, 12, 13, 14, 15, 16, 17, 18]
DEV_PEOPLE_ID = [19, 20, 21, 23, 24, 25, 1, 4]
TEST_PEOPLE_ID = [22, 2, 3, 5, 6, 7, 8, 9, 10]

# %% [markdown]
# ## Preparing Dataset

# %%
def prepare_dataset(dataset="train", sequences=None):
    if dataset == "train":
        ID = TRAIN_PEOPLE_ID
    elif dataset == "dev":
        ID = DEV_PEOPLE_ID
    else:
        ID = TEST_PEOPLE_ID

    if sequences == None:
      frames_idx = clean_sequence_file()
    else:
      frames_idx = sequences

    data = []
    
    for category in CATEGORIES:
        # Get all files in current category's folder.
        folder_path = os.path.join("", "dataset", category)
        filenames = sorted(os.listdir(folder_path))

        for filename in filenames:
            filepath = os.path.join("", "dataset", category, filename)

            # Get id of person in this video.
            person_id = int(filename.split("_")[0][6:])
            if person_id not in ID:
                continue

            vid = imageio.get_reader(filepath, "ffmpeg")

            frames = []

            # Add each frame to correct list.
            for i, frame in enumerate(vid):
                # Boolean flag to check if current frame contains human.
                ok = False
                for seg in frames_idx[filename]:
                    if i >= seg[0] and i <= seg[1]:
                        ok = True
                        break
                if not ok:
                    continue

                # Convert to grayscale.
                frame = Image.fromarray(np.array(frame))
                frame = frame.convert("L")
                frame = np.array(frame.getdata(),
                                 dtype=np.uint8).reshape((120, 160))
                #frame = imresize(frame, (60, 80))

                frames.append(frame)

            data.append({
                "filename": filename,
                "category": category,
                "frames": frames    
            })

    pickle.dump(data, open("data/%s.p" % dataset, "wb+"))

# %%
def clean_sequence_file():
    print("Cleaning dataset/00sequences.txt ...")

    # Read 00sequences.txt file.
    with open('dataset/00sequences.txt', 'r') as content_file:
      for _ in range(20): # Skiping first 20 lines of sequences file (instruction details).
        next(content_file)
      content = content_file.read()

    # Replace tab and newline character with space, then split file's content
    # into strings.
    content = re.sub("[\t\n]", " ", content).split()

    # Dictionary to keep ranges of frames with humans.
    # Example:
    # video "person01_boxing_d1": [(1, 95), (96, 185), (186, 245), (246, 360)].
    frames_idx = {}

    # Current video that we are parsing.
    current_filename = ""

    for s in content:
        if s == "frames":
            # Ignore this token.
            continue
        elif s.find("-") >= 0:
            # This is the token we are looking for. e.g. 1-95.
            if s[len(s) - 1] == ',':
                # Remove comma.
                s = s[:-1]

            # Split into 2 numbers => [1, 95]
            idx = s.split("-")

            # Add to dictionary.
            if not current_filename in frames_idx:
                frames_idx[current_filename] = []
            frames_idx[current_filename].append((int(idx[0]), int(idx[1])))
        else:
            # Parse next file.
            current_filename = s + "_uncomp.avi"

    return frames_idx

# %%
extracted_sequences = clean_sequence_file()
print("Preparing train dataset ...")
prepare_dataset(dataset="train", sequences=extracted_sequences)
print("Preparing dev dataset ...")
prepare_dataset(dataset="dev", sequences=extracted_sequences)
print("Preparing test dataset ...")
prepare_dataset(dataset="test", sequences=extracted_sequences)
# Out:
# Cleaning dataset/00sequences.txt ...
# Preparing train dataset ...
# Preparing dev dataset ...
# Preparing test dataset ...
